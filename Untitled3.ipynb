# %% [markdown]
# <a href="https://colab.research.google.com/github/Mago49/Deppteste/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow keras matplotlib

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
import tensorflow_datasets as tfds

(train_ds, val_ds), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    with_info=True
)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/cats_vs_dogs/4.0.1 has no dataset_info.json
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling /root/tensorflow_datasets/cats_vs_dogs/incomplete.823LC7_4.0.1/cats_vs_dogs-train.tfrecord*...:   0%…
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.1. Subsequent calls will reuse this data.

# %%
IMG_SIZE = 160  # Dimensão padrão para modelos pré-treinados
def format_example(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = image / 255.0
    return image, label

train = train_ds.map(format_example).batch(32)
val = val_ds.map(format_example).batch(32)

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=(IMG_SIZE, IMG_SIZE, 3),
                                               include_top=False,
                                               weights='imagenet')

base_model.trainable = False  # Congela os pesos

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
history = model.fit(train, validation_data=val, epochs=3)
# Out:
# Epoch 1/3
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 486s 812ms/step - accuracy: 0.9306 - loss: 0.1634 - val_accuracy: 0.9779 - val_loss: 0.0638
# Epoch 2/3
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 475s 816ms/step - accuracy: 0.9805 - loss: 0.0583 - val_accuracy: 0.9807 - val_loss: 0.0594
# Epoch 3/3
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.9826 - loss: 0.0516

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend()
plt.show()
